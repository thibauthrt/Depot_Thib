# %% [markdown]
# ### Exercice 2

# %%
liste=[i**2-2*i+3 for i in range(0,11)]

# %%
def fonction(x,y):
    liste=[]
    for n in range(11):
        A=n**2-2*n+3
        liste.append(A)
    return liste
fonction(1,-1)
# Out:
# [3, 2, 3, 6, 11, 18, 27, 38, 51, 66, 83]

# %% [markdown]
# ### Exercice 3

# %%
list2=[45,17,89,38,10,74]

# %%
list2[1:3]
# Out:
# [17, 89]

# %% [markdown]
# ### Exercice 4

# %%
liste3=[]
def fonction2(n):
    for n in range(n):
        B=1
        liste3.append(B)
        B=1+n
        liste3.append(B)
    return liste3
fonction2(5)
# Out:
# [1, 1, 1, 2, 1, 3, 1, 4, 1, 5]

# %% [markdown]
# ### Exercice 5

# %%
nb = [10, 45, 2, 89, 34]

maxval = nb[0]

for n in nb:
    if n > maxval:
        maxval = n

print(maxval)
# Out:
# 89

# %%
nb2 = [10, 45, 2, 89, 34]
maximum = max(nb2)
print(maximum)
# Out:
# 89
